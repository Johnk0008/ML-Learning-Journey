# %% [markdown]
# # Data Gathering

# %%
import pandas as pd
import requests

# %% [markdown]
# ## API Key paste

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=f563fb11128520e7ce34efd8a0a37887&language=en-US&page=1')

# %% [markdown]
# ## Col Select code

# %%
df = pd.DataFrame(response.json()['results'])[['id','title','release_date','overview','popularity','vote_average','vote_count']]

# %% [markdown]
# ## DF Show

# %%
df.head()
# Out:
#     id                     title release_date  \
# 0  278  The Shawshank Redemption   1994-09-23
# 1  238             The Godfather   1972-03-14
# 2  240     The Godfather Part II   1974-12-20
# 3  424          Schindler's List   1993-12-15
# 4  389              12 Angry Men   1957-04-10
#
#                                             overview  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...     28.7871
# 1  Spanning the years 1945 to 1955, a chronicle o...     26.5320
# 2  In the continuing saga of the Corleone crime f...     16.4850
# 3  The true story of how businessman Oskar Schind...     11.5738
# 4  The defense and the prosecution have rested an...     13.0826
#
#    vote_average  vote_count
# 0         8.712       28848
# 1         8.686       21807
# 2         8.571       13172
# 3         8.566       16686
# 4         8.548        9376

# %% [markdown]
# ## Get a Api data from page 3

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=f563fb11128520e7ce34efd8a0a37887&language=en-US&page=3')

# %%
df.head()
# Out:
#     id                     title release_date  \
# 0  278  The Shawshank Redemption   1994-09-23
# 1  238             The Godfather   1972-03-14
# 2  240     The Godfather Part II   1974-12-20
# 3  424          Schindler's List   1993-12-15
# 4  389              12 Angry Men   1957-04-10
#
#                                             overview  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...     28.7871
# 1  Spanning the years 1945 to 1955, a chronicle o...     26.5320
# 2  In the continuing saga of the Corleone crime f...     16.4850
# 3  The true story of how businessman Oskar Schind...     11.5738
# 4  The defense and the prosecution have rested an...     13.0826
#
#    vote_average  vote_count
# 0         8.712       28848
# 1         8.686       21807
# 2         8.571       13172
# 3         8.566       16686
# 4         8.548        9376

# %%
df1 = pd.DataFrame(response.json()['results'])[['id','title','release_date','overview','popularity','vote_average','backdrop_path']]

# %%
df1
# Out:
#          id                                 title release_date  \
# 0       807                                 Se7en   1995-09-22
# 1    761053           Gabriel's Inferno: Part III   2020-11-19
# 2    724089            Gabriel's Inferno: Part II   2020-07-31
# 3     27205                             Inception   2010-07-15
# 4   1058694                               Radical   2023-10-19
# 5    803796                    KPop Demon Hunters   2025-06-20
# 6       567                           Rear Window   1954-08-01
# 7       274              The Silence of the Lambs   1991-02-14
# 8     12493                          High and Low   1963-03-01
# 9    569094   Spider-Man: Across the Spider-Verse   2023-05-31
# 10       73                    American History X   1998-07-01
# 11   820067  The Quintessential Quintuplets Movie   2022-05-20
# 12   372754              Dou kyu sei – Classmates   2016-02-20
# 13      128                     Princess Mononoke   1997-07-12
# ...

# %%
df1.shape
# Out:
# (20, 7)

# %% [markdown]
# # Convert Data into CSV File Format

# %%
df1.to_csv('movies.csv')

# %%
df1
# Out:
#          id                                 title release_date  \
# 0       807                                 Se7en   1995-09-22
# 1    761053           Gabriel's Inferno: Part III   2020-11-19
# 2    724089            Gabriel's Inferno: Part II   2020-07-31
# 3     27205                             Inception   2010-07-15
# 4   1058694                               Radical   2023-10-19
# 5    803796                    KPop Demon Hunters   2025-06-20
# 6       567                           Rear Window   1954-08-01
# 7       274              The Silence of the Lambs   1991-02-14
# 8     12493                          High and Low   1963-03-01
# 9    569094   Spider-Man: Across the Spider-Verse   2023-05-31
# 10       73                    American History X   1998-07-01
# 11   820067  The Quintessential Quintuplets Movie   2022-05-20
# 12   372754              Dou kyu sei – Classmates   2016-02-20
# 13      128                     Princess Mononoke   1997-07-12
# ...

# %%
df.to_csv('movies_Page1.csv')

# %%
df
# Out:
#         id                                          title release_date  \
# 0      278                       The Shawshank Redemption   1994-09-23
# 1      238                                  The Godfather   1972-03-14
# 2      240                          The Godfather Part II   1974-12-20
# 3      424                               Schindler's List   1993-12-15
# 4      389                                   12 Angry Men   1957-04-10
# 5      129                                  Spirited Away   2001-07-20
# 6      155                                The Dark Knight   2008-07-16
# 7    19404                    Dilwale Dulhania Le Jayenge   1995-10-20
# 8      497                                 The Green Mile   1999-12-10
# 9   496243                                       Parasite   2019-05-30
# 10     122  The Lord of the Rings: The Return of the King   2003-12-17
# 11     680                                   Pulp Fiction   1994-09-10
# ...
